# %%
import pandas as pd

# %% [markdown]
# ** import global supersales dataset using pandas

# %%
df = pd.read_excel("C:\\Users\\sippy\\Downloads\\sales data.xlsx")

# %%
df.head()
# Out:
#    Row ID        Order ID  Month  Order Date  Ship Date       Ship Mode  \
# 0       1  CA-2017-152156      11 2017-11-08 2017-11-11    Second Class
# 1       2  CA-2017-152156      11 2017-11-08 2017-11-11    Second Class
# 2       3  CA-2017-138688       6 2017-06-12 2017-06-16    Second Class
# 3       4  US-2016-108966      10 2016-10-11 2016-10-18  Standard Class
# 4       5  US-2016-108966      10 2016-10-11 2016-10-18  Standard Class
#
#   Customer ID    Customer Name    Segment        Country             City  \
# 0    CG-12520      Claire Gute   Consumer  United States        Henderson
# 1    CG-12520      Claire Gute   Consumer  United States        Henderson
# 2    DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#         State  Postal Code Region       Product ID         Category  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Row ID        Order ID  Month  Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2017-152156      11 2017-11-08 2017-11-11    Second Class
# 1          2  CA-2017-152156      11 2017-11-08 2017-11-11    Second Class
# 2          3  CA-2017-138688       6 2017-06-12 2017-06-16    Second Class
# 3          4  US-2016-108966      10 2016-10-11 2016-10-18  Standard Class
# 4          5  US-2016-108966      10 2016-10-11 2016-10-18  Standard Class
# ...      ...             ...     ...        ...        ...             ...
# 9795    9796  CA-2017-125920       5 2017-05-21 2017-05-28  Standard Class
# 9796    9797  CA-2016-128608       1 2016-01-12 2016-01-17  Standard Class
# 9797    9798  CA-2016-128608       1 2016-01-12 2016-01-17  Standard Class
# 9798    9799  CA-2016-128608       1 2016-01-12 2016-01-17  Standard Class
# 9799    9800  CA-2016-128608       1 2016-01-12 2016-01-17  Standard Class
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Month          9800 non-null   int64
#  3   Order Date     9800 non-null   datetime64[ns]
#  4   Ship Date      9800 non-null   datetime64[ns]
#  5   Ship Mode      9800 non-null   object
#  6   Customer ID    9800 non-null   object
#  7   Customer Name  9800 non-null   object
#  8   Segment        9800 non-null   object
#  9   Country        9800 non-null   object
#  10  City           9800 non-null   object
#  11  State          9800 non-null   object
#  12  Postal Code    9789 non-null   float64
#  13  Region         9800 non-null   object
#  14  Product ID     9800 non-null   object
#  15  Category       9800 non-null   object
#  16  Sub-Category   9800 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Month             0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Month .1          0
# dtype: int64

# %%
duplicates = df.duplicated().sum()

df = df.drop_duplicates()

# %% [markdown]
#  ## verify duplicates removed

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Convert order date and ship date format

# %%
df['Order Date'] = pd.to_datetime(df['Order Date']) 
df['Ship Date '] = pd.to_datetime(df['Ship Date'])

# %% [markdown]
# ### Verify datatypes

# %%
print(df.dtypes)
# Out:
# Row ID                    int64
# Order ID                 object
# Month                     int64
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code             float64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Month .1                  int64
# Ship Date        datetime64[ns]
# dtype: object

# %%
df.to_csv("Cleaned_Global_Sales.csv",index = False ) 

print ("Data Cleaning compeleted successfully!!") 
print(" Cleaned file saves as 'Cleaned_Global_Sales.csv' ")
# Out:
# Data Cleaning compeleted successfully!!
#  Cleaned file saves as 'Cleaned_Global_Sales.csv'

# %%
df.head()
# Out:
#    Row ID        Order ID  Month  Order Date  Ship Date       Ship Mode  \
# 0       1  CA-2017-152156      11 2017-11-08 2017-11-11    Second Class
# 1       2  CA-2017-152156      11 2017-11-08 2017-11-11    Second Class
# 2       3  CA-2017-138688       6 2017-06-12 2017-06-16    Second Class
# 3       4  US-2016-108966      10 2016-10-11 2016-10-18  Standard Class
# 4       5  US-2016-108966      10 2016-10-11 2016-10-18  Standard Class
#
#   Customer ID    Customer Name    Segment        Country  ...       State  \
# 0    CG-12520      Claire Gute   Consumer  United States  ...    Kentucky
# 1    CG-12520      Claire Gute   Consumer  United States  ...    Kentucky
# 2    DV-13045  Darrin Van Huff  Corporate  United States  ...  California
# 3    SO-20335   Sean O'Donnell   Consumer  United States  ...     Florida
# 4    SO-20335   Sean O'Donnell   Consumer  United States  ...     Florida
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.head(10)
# Out:
#    Row ID        Order ID  Month  Order Date  Ship Date       Ship Mode  \
# 0       1  CA-2017-152156      11 2017-11-08 2017-11-11    Second Class
# 1       2  CA-2017-152156      11 2017-11-08 2017-11-11    Second Class
# 2       3  CA-2017-138688       6 2017-06-12 2017-06-16    Second Class
# 3       4  US-2016-108966      10 2016-10-11 2016-10-18  Standard Class
# 4       5  US-2016-108966      10 2016-10-11 2016-10-18  Standard Class
# 5       6  CA-2015-115812       6 2015-06-09 2015-06-14  Standard Class
# 6       7  CA-2015-115812       6 2015-06-09 2015-06-14  Standard Class
# 7       8  CA-2015-115812       6 2015-06-09 2015-06-14  Standard Class
# 8       9  CA-2015-115812       6 2015-06-09 2015-06-14  Standard Class
# 9      10  CA-2015-115812       6 2015-06-09 2015-06-14  Standard Class
#
#   Customer ID    Customer Name    Segment        Country  ...       State  \
# 0    CG-12520      Claire Gute   Consumer  United States  ...    Kentucky
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID  Month  Order Date  Ship Date       Ship Mode  \
# 9795    9796  CA-2017-125920       5 2017-05-21 2017-05-28  Standard Class
# 9796    9797  CA-2016-128608       1 2016-01-12 2016-01-17  Standard Class
# 9797    9798  CA-2016-128608       1 2016-01-12 2016-01-17  Standard Class
# 9798    9799  CA-2016-128608       1 2016-01-12 2016-01-17  Standard Class
# 9799    9800  CA-2016-128608       1 2016-01-12 2016-01-17  Standard Class
#
#      Customer ID     Customer Name    Segment        Country  ...     State  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  ...  Illinois
# 9796    CS-12490  Cindy Schnelling  Corporate  United States  ...      Ohio
# 9797    CS-12490  Cindy Schnelling  Corporate  United States  ...      Ohio
# 9798    CS-12490  Cindy Schnelling  Corporate  United States  ...      Ohio
# 9799    CS-12490  Cindy Schnelling  Corporate  United States  ...      Ohio
#
# ...

# %%
print(df.shape)
# Out:
# (9800, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Month          9800 non-null   int64
#  3   Order Date     9800 non-null   datetime64[ns]
#  4   Ship Date      9800 non-null   datetime64[ns]
#  5   Ship Mode      9800 non-null   object
#  6   Customer ID    9800 non-null   object
#  7   Customer Name  9800 non-null   object
#  8   Segment        9800 non-null   object
#  9   Country        9800 non-null   object
#  10  City           9800 non-null   object
#  11  State          9800 non-null   object
#  12  Postal Code    9789 non-null   float64
#  13  Region         9800 non-null   object
#  14  Product ID     9800 non-null   object
#  15  Category       9800 non-null   object
#  16  Sub-Category   9800 non-null   object
# ...
